# %%
import pandas as pd
df=pd.read_csv('Salary_dataset.csv')

# %%
from sklearn.model_selection import train_test_split
#Necessary columns for plotting
#x-> years of experience
#y-> salary
x=df[['YearsExperience']]
y=df['Salary']

X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(X_train,y_train)

y_predicted=model.predict(X_test)
print("Intercept: ",model.intercept_)
print("Slope: ",model.coef_)
print("Actual data: ",list(y_test.values))
print("Predicted data: ",list(y_predicted))
# Out:
# Intercept:  24985.53016251169
# Slope:  [9339.08172382]
# Actual data:  [np.float64(112636.0), np.float64(67939.0), np.float64(113813.0), np.float64(83089.0), np.float64(64446.0), np.float64(57190.0), np.float64(122392.0), np.float64(109432.0), np.float64(56958.0)]
# Predicted data:  [np.float64(115574.6228835191), np.float64(71680.93878158767), np.float64(102499.90847017782), np.float64(75416.57147111377), np.float64(55804.49985110185), np.float64(60474.04071300944), np.float64(122111.98009018975), np.float64(107169.44933208541), np.float64(63275.765230154)]

# %%
#testing for user input
years=7.5
predicted=model.predict([[years]])

print(f"Predicted salary for {years} years: {predicted}")
# Out:
# Predicted salary for 7.5 years: [95028.64309113]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
